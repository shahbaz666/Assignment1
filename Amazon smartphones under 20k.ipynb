# %%
#Main function for smartphones under 20k
def amazon_smartphones():
    #Import Modules
    import csv
    from bs4 import BeautifulSoup
    from selenium import webdriver
    
    #Function for extracting info from one search result
    def extract_record(item):
        """extract and return result from a single result"""
        #description and url
        atag = item.h2.a
        description = atag.text.strip()
        url = 'https://www.amazon.in' + atag.get('href')
    
        try:
            #price
            price_parent = item.find('span', 'a-price')
            price = price_parent.find('span', 'a-offscreen').text
        except AttributeError:
            return
    
        try:
            #rating
            rating = item.i.text
        except AttributeError:
            return
    
        result = (description, price, rating, url)
    
        return result
    
    #function for moving to next page
    def next_page_url():
        anc_tag = soup.find('li',{"class":"a-last"})
        next_url = anc_tag.a
        nurl = 'https://www.amazon.in' + next_url.get('href')
        return nurl
    
    driver = webdriver.Chrome()
    records = []
    
    for page in range(1,12):
        if page==1:
            url = 'https://www.amazon.in/s?k=mobile+phone+under+20000&crid=32XZ005X0CN9R&sprefix=mobile+pho%2Caps%2C313&ref=nb_sb_noss_2'
        else:
            url = next_page_url()
        driver.get(url)
        soup = BeautifulSoup(driver.page_source,'html.parser')
        results = soup.find_all('div',{"data-component-type":"s-search-result"})
    
        for item in results:
            record = extract_record(item)
            if record:
                records.append(record)
    driver.close()
    return records

# %%
print(amazon_smartphones())
# Out:
# [('Redmi Note 9 Pro (Champagne Gold, 4GB RAM, 128GB Storage) - Latest 8nm Snapdragon 720G & Alexa Hands-Free', '₹13,999', '4.2 out of 5 stars', 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A02597803E0GOI0Q13IO&url=%2FRedmi-Note-Pro-Champagne-Storage%2Fdp%2FB086977J4T%2Fref%3Dsr_1_1_sspa%3Fcrid%3D32XZ005X0CN9R%26dchild%3D1%26keywords%3Dmobile%2Bphone%2Bunder%2B20000%26sprefix%3Dmobile%2Bpho%252Caps%252C313%26sr%3D8-1-spons%26psc%3D1&qualifier=1604715085&id=5951886051862470&widgetName=sp_atf'), ('Redmi Note 9 Pro (Glacier White, 4GB RAM, 128GB Storage) - Latest 8nm Snapdragon 720G & Alexa Hands-Free | 6 Months No Cost EMI', '₹13,999', '4.2 out of 5 stars', 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A026033619IHU6OI9I9ZV&url=%2FRedmi-Note-Pro-Snapdragon-Protection%2Fdp%2FB086982ZKP%2Fref%3Dsr_1_2_sspa%3Fcrid%3D32XZ005X0CN9R%26dchild%3D1%26keywords%3Dmobile%2Bphone%2Bunder%2B20000%26sprefix%3Dmobile%2Bpho%252Caps%252C313%26sr%3D8-2-spons%26psc%3D1&qualifier=1604715085&id=5951886051862470&widgetName=sp_atf'), ('Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 64GB Storage)- Latest 8nm Snapdragon 720G & Alexa Hands-Free', '₹12,999', '4.2 out of 5 stars', 'https://www.amazon.in/Redmi-Note-Pro-Interstellar-Snapdragon/dp/B077PWBC78/ref=sr_1_3?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-3'), ('Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage) - Get Rs 1,000 Amazon Pay cashback on prepaid orders. Limited Period offer', '₹16,499', '4.2 out of 5 stars', 'https://www.amazon.in/Samsung-Galaxy-Ocean-128GB-Storage/dp/B07HGGYWL6/ref=sr_1_4?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-4'), ('Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery', '₹6,999', '4.0 out of 5 stars', 'https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/dp/B07X4R63DF/ref=sr_1_5?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-5'), ('Samsung Galaxy M01 (Black, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers', '₹7,999', '3.9 out of 5 stars', 'https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B086KCCMCP/ref=sr_1_6?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-6'), ('OPPO A5 2020 (Dazzling White, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers', '₹11,990', '4.1 out of 5 stars', 'https://www.amazon.in/Dazzling-Storage-Additional-Exchange-Offers/dp/B07SDPJ4XJ/ref=sr_1_7?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-7'), ('Samsung Galaxy M21 (Midnight Blue, 6GB RAM, 128GB Storage)', '₹14,999', '4.2 out of 5 stars', 'https://www.amazon.in/Samsung-Galaxy-Midnight-128GB-Storage/dp/B07HGH88GL/ref=sr_1_8?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-8'), ('Samsung Galaxy M01 (Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers', '₹7,999', '3.9 out of 5 stars', 'https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B086KCDGTQ/ref=sr_1_9?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-9'), ('Samsung Galaxy M01 Core (Blue, 1GB RAM, 16GB Storage) with No Cost EMI/Additional Exchange Offers', '₹5,000', '3.2 out of 5 stars', 'https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B089MS3GLM/ref=sr_1_10?crid=32XZ005X0CN9R&dchild=1&keywords=mobile+phone+under+20000&sprefix=mobile+pho%2Caps%2C313&sr=8-10'), ('Samsung Galaxy Note10 Lite (Aura Black, 6GB RAM, 128GB Storage)\xa0with No Cost EMI/Additional Exchange Offers', '₹37,999', '4.1 out of 5 stars', 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_mtf_aps_sr_pg1_1?ie=UTF8&adId=A018258825NL93JL3UKXI&url=%2FSamsung-Galaxy-Stora ...
